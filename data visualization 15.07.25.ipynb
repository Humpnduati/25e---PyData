# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r'/home/humpnduati/DATA_SCIENCE/25e---PyData/Data_Sets/train.xlsx')
df
# Out:
#        ID                 date  Meals served  kitchen_staff  temperature_C  \
# 0       0           19/12/2022           196             13      27.887273
# 1       1           21/11/2023           244             15      10.317872
# 2       4  2022-01-02 00:00:00           148             16      27.714300
# 3       5           19/03/2023           157             19      19.173902
# 4       6           18/07/2022           297             10      26.375233
# ..    ...                  ...           ...            ...            ...
# 909  1048           14/02/2022           406             10      19.061638
# 910  1049  2024-10-05 00:00:00           350              6      23.708015
# 911     6           18/07/2022           297             10      26.375233
# 912  1037           13/08/2024           338             17      30.509438
# 913  1000           16/06/2024           372             17      31.549673
#
#      humidity_percent  Day of the week  special_event  past_waste_kg  \
# 0           45.362854                0              0       7.740587
# 1           64.430475                1              0      42.311779
# 2           69.046113                1              0      41.184305
# 3           46.292823                6              0      41.543492
# 4           79.741064                0              0      26.525097
# ..                ...              ...            ...            ...
# 909         55.286642                0              0      28.560361
# 910         51.351286                4              0      46.786860
# 911         79.741064                0              0      26.525097
# 912         79.102174                1              0      43.168167
# 913         65.721580                6              0      38.747916
#
#     staff_experience WASTE CATEGORY           food_waste_kg
# 0       intermediate          dairy  28.946465336432905  kg
# 1                NaN            NaN   51.54905281454645  kg
# 2           Beginner           MeAt  53.008322732556536  kg
# 3           Beginner           MeAt   48.62152711280995  kg
# 4       Intermediate           MEAT   44.15698435866615  kg
# ..               ...            ...                     ...
# 909           EXPERT           MEAT  44.615759364510275  kg
# 910     intermediate     Vegetables    57.0664809637605  kg
# 911     Intermediate           MEAT   44.15698435866615  kg
# 912     Intermediate           MEAT  48.366656560992055  kg
# 913     Intermediate           MeAt  49.347464797924786  kg
#
# [914 rows x 12 columns]

# %%
df.dtypes
# Out:
# ID                    int64
# date                 object
# Meals served          int64
# kitchen_staff         int64
# temperature_C       float64
# humidity_percent    float64
# Day of the week       int64
# special_event         int64
# past_waste_kg       float64
# staff_experience     object
# WASTE CATEGORY       object
# food_waste_kg        object
# dtype: object

# %%
df['food_waste_kg']=df['food_waste_kg'].str.replace('kg', ' ').astype(float)
df['food_waste_kg'].dtype
# Out:
# dtype('float64')

# %%
df['WASTE CATEGORY']=df['WASTE CATEGORY'].str.lower()
df
# Out:
#        ID                 date  Meals served  kitchen_staff  temperature_C  \
# 0       0           19/12/2022           196             13      27.887273
# 1       1           21/11/2023           244             15      10.317872
# 2       4  2022-01-02 00:00:00           148             16      27.714300
# 3       5           19/03/2023           157             19      19.173902
# 4       6           18/07/2022           297             10      26.375233
# ..    ...                  ...           ...            ...            ...
# 909  1048           14/02/2022           406             10      19.061638
# 910  1049  2024-10-05 00:00:00           350              6      23.708015
# 911     6           18/07/2022           297             10      26.375233
# 912  1037           13/08/2024           338             17      30.509438
# 913  1000           16/06/2024           372             17      31.549673
#
#      humidity_percent  Day of the week  special_event  past_waste_kg  \
# 0           45.362854                0              0       7.740587
# 1           64.430475                1              0      42.311779
# 2           69.046113                1              0      41.184305
# 3           46.292823                6              0      41.543492
# 4           79.741064                0              0      26.525097
# ..                ...              ...            ...            ...
# 909         55.286642                0              0      28.560361
# 910         51.351286                4              0      46.786860
# 911         79.741064                0              0      26.525097
# 912         79.102174                1              0      43.168167
# 913         65.721580                6              0      38.747916
#
#     staff_experience WASTE CATEGORY  food_waste_kg
# 0       intermediate          dairy      28.946465
# 1                NaN            NaN      51.549053
# 2           Beginner           meat      53.008323
# 3           Beginner           meat      48.621527
# 4       Intermediate           meat      44.156984
# ..               ...            ...            ...
# 909           EXPERT           meat      44.615759
# 910     intermediate     vegetables      57.066481
# 911     Intermediate           meat      44.156984
# 912     Intermediate           meat      48.366657
# 913     Intermediate           meat      49.347465
#
# [914 rows x 12 columns]

# %%
df['staff_experience']=df['staff_experience'].str.lower()
df
# Out:
#        ID                 date  Meals served  kitchen_staff  temperature_C  \
# 0       0           19/12/2022           196             13      27.887273
# 1       1           21/11/2023           244             15      10.317872
# 2       4  2022-01-02 00:00:00           148             16      27.714300
# 3       5           19/03/2023           157             19      19.173902
# 4       6           18/07/2022           297             10      26.375233
# ..    ...                  ...           ...            ...            ...
# 909  1048           14/02/2022           406             10      19.061638
# 910  1049  2024-10-05 00:00:00           350              6      23.708015
# 911     6           18/07/2022           297             10      26.375233
# 912  1037           13/08/2024           338             17      30.509438
# 913  1000           16/06/2024           372             17      31.549673
#
#      humidity_percent  Day of the week  special_event  past_waste_kg  \
# 0           45.362854                0              0       7.740587
# 1           64.430475                1              0      42.311779
# 2           69.046113                1              0      41.184305
# 3           46.292823                6              0      41.543492
# 4           79.741064                0              0      26.525097
# ..                ...              ...            ...            ...
# 909         55.286642                0              0      28.560361
# 910         51.351286                4              0      46.786860
# 911         79.741064                0              0      26.525097
# 912         79.102174                1              0      43.168167
# 913         65.721580                6              0      38.747916
#
#     staff_experience WASTE CATEGORY  food_waste_kg
# 0       intermediate          dairy      28.946465
# 1                NaN            NaN      51.549053
# 2           beginner           meat      53.008323
# 3           beginner           meat      48.621527
# 4       intermediate           meat      44.156984
# ..               ...            ...            ...
# 909           expert           meat      44.615759
# 910     intermediate     vegetables      57.066481
# 911     intermediate           meat      44.156984
# 912     intermediate           meat      48.366657
# 913     intermediate           meat      49.347465
#
# [914 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['ID', 'date', 'Meals served', 'kitchen_staff', 'temperature_C',
#        'humidity_percent', 'Day of the week', 'special_event', 'past_waste_kg',
#        'staff_experience', 'WASTE CATEGORY', 'food_waste_kg'],
#       dtype='object')

# %%
df.rename(columns ={
    'Meals served' : 'meals_served',
    'Day of the week' : 'day_of_the_week',
    'WASTE CATEGORY' : 'waste_category'
}, inplace=True)

# %%
df
# Out:
#        ID                 date  meals_served  kitchen_staff  temperature_C  \
# 0       0           19/12/2022           196             13      27.887273
# 1       1           21/11/2023           244             15      10.317872
# 2       4  2022-01-02 00:00:00           148             16      27.714300
# 3       5           19/03/2023           157             19      19.173902
# 4       6           18/07/2022           297             10      26.375233
# ..    ...                  ...           ...            ...            ...
# 909  1048           14/02/2022           406             10      19.061638
# 910  1049  2024-10-05 00:00:00           350              6      23.708015
# 911     6           18/07/2022           297             10      26.375233
# 912  1037           13/08/2024           338             17      30.509438
# 913  1000           16/06/2024           372             17      31.549673
#
#      humidity_percent  day_of_the_week  special_event  past_waste_kg  \
# 0           45.362854                0              0       7.740587
# 1           64.430475                1              0      42.311779
# 2           69.046113                1              0      41.184305
# 3           46.292823                6              0      41.543492
# 4           79.741064                0              0      26.525097
# ..                ...              ...            ...            ...
# 909         55.286642                0              0      28.560361
# 910         51.351286                4              0      46.786860
# 911         79.741064                0              0      26.525097
# 912         79.102174                1              0      43.168167
# 913         65.721580                6              0      38.747916
#
#     staff_experience waste_category  food_waste_kg
# 0       intermediate          dairy      28.946465
# 1                NaN            NaN      51.549053
# 2           beginner           meat      53.008323
# 3           beginner           meat      48.621527
# 4       intermediate           meat      44.156984
# ..               ...            ...            ...
# 909           expert           meat      44.615759
# 910     intermediate     vegetables      57.066481
# 911     intermediate           meat      44.156984
# 912     intermediate           meat      48.366657
# 913     intermediate           meat      49.347465
#
# [914 rows x 12 columns]

# %%
df.duplicated().value_counts()
# Out:
# False    911
# True       3
# Name: count, dtype: int64

# %%
df[df.duplicated()]
# Out:
#        ID        date  meals_served  kitchen_staff  temperature_C  \
# 911     6  18/07/2022           297             10      26.375233
# 912  1037  13/08/2024           338             17      30.509438
# 913  1000  16/06/2024           372             17      31.549673
#
#      humidity_percent  day_of_the_week  special_event  past_waste_kg  \
# 911         79.741064                0              0      26.525097
# 912         79.102174                1              0      43.168167
# 913         65.721580                6              0      38.747916
#
#     staff_experience waste_category  food_waste_kg
# 911     intermediate           meat      44.156984
# 912     intermediate           meat      48.366657
# 913     intermediate           meat      49.347465

# %%
print(df.shape)
print('_'*7)
df_clean=df.drop_duplicates()
print(df_clean.shape)
# Out:
# (914, 12)
# _______
# (911, 12)

# %%
#ways to identify missingness
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 911 entries, 0 to 910
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                911 non-null    int64
#  1   date              911 non-null    object
#  2   meals_served      911 non-null    int64
#  3   kitchen_staff     911 non-null    int64
#  4   temperature_C     911 non-null    float64
#  5   humidity_percent  909 non-null    float64
#  6   day_of_the_week   911 non-null    int64
#  7   special_event     911 non-null    int64
#  8   past_waste_kg     911 non-null    float64
#  9   staff_experience  747 non-null    object
#  10  waste_category    892 non-null    object
#  11  food_waste_kg     911 non-null    float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 92.5+ KB

# %%
#ways to identify missigness
df_clean.isnull().sum()
# Out:
# ID                    0
# date                  0
# meals_served          0
# kitchen_staff         0
# temperature_C         0
# humidity_percent      2
# day_of_the_week       0
# special_event         0
# past_waste_kg         0
# staff_experience    164
# waste_category       19
# food_waste_kg         0
# dtype: int64

# %%
#ways to identify missingness
df_clean.notnull()
# Out:
#        ID  date  meals_served  kitchen_staff  temperature_C  humidity_percent  \
# 0    True  True          True           True           True              True
# 1    True  True          True           True           True              True
# 2    True  True          True           True           True              True
# 3    True  True          True           True           True              True
# 4    True  True          True           True           True              True
# ..    ...   ...           ...            ...            ...               ...
# 906  True  True          True           True           True              True
# 907  True  True          True           True           True              True
# 908  True  True          True           True           True              True
# 909  True  True          True           True           True              True
# 910  True  True          True           True           True              True
#
#      day_of_the_week  special_event  past_waste_kg  staff_experience  \
# 0               True           True           True              True
# 1               True           True           True             False
# 2               True           True           True              True
# 3               True           True           True              True
# 4               True           True           True              True
# ..               ...            ...            ...               ...
# 906             True           True           True              True
# 907             True           True           True              True
# 908             True           True           True              True
# 909             True           True           True              True
# 910             True           True           True              True
#
#      waste_category  food_waste_kg
# 0              True           True
# 1             False           True
# 2              True           True
# 3              True           True
# 4              True           True
# ..              ...            ...
# 906           False           True
# 907            True           True
# 908            True           True
# 909            True           True
# 910            True           True
#
# [911 rows x 12 columns]

# %%
#quantify missingness
total_missing = df_clean.isnull().sum()
total_values = df_clean.isnull().count()

percent_missing = total_missing/total_values
percent_missing*100
# Out:
# ID                   0.000000
# date                 0.000000
# meals_served         0.000000
# kitchen_staff        0.000000
# temperature_C        0.000000
# humidity_percent     0.219539
# day_of_the_week      0.000000
# special_event        0.000000
# past_waste_kg        0.000000
# staff_experience    18.002195
# waste_category       2.085620
# food_waste_kg        0.000000
# dtype: float64

# %%
#quantify missingness
import missingno as mn
mn.matrix(df_clean)
# Out:
# <Axes: >

# %%
df_clean['humidity_percent'].fillna((df_clean['humidity_percent'].mean()),inplace=True)
df_clean.info()
# Out:
# /tmp/ipykernel_11920/3426258634.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['humidity_percent'].fillna((df_clean['humidity_percent'].mean()),inplace=True)
# /tmp/ipykernel_11920/3426258634.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['humidity_percent'].fillna((df_clean['humidity_percent'].mean()),inplace=True)
# <class 'pandas.core.frame.DataFrame'>
# Index: 911 entries, 0 to 910
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                911 non-null    int64
#  1   date              911 non-null    object
#  2   meals_served      911 non-null    int64
#  3   kitchen_staff     911 non-null    int64
#  4   temperature_C     911 non-null    float64
#  5   humidity_percent  911 non-null    float64
#  6   day_of_the_week   911 non-null    int64
#  7   special_event     911 non-null    int64
#  8   past_waste_kg     911 non-null    float64
#  9   staff_experience  747 non-null    object
#  10  waste_category    892 non-null    object
#  11  food_waste_kg     911 non-null    float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 92.5+ KB

# %%
df_clean['waste_category'].fillna((df_clean['waste_category'].mode()[0]),inplace = True)
# Out:
# /tmp/ipykernel_11920/1607490956.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['waste_category'].fillna((df_clean['waste_category'].mode()[0]),inplace = True)
# /tmp/ipykernel_11920/1607490956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['waste_category'].fillna((df_clean['waste_category'].mode()[0]),inplace = True)

# %%
df_clean['staff_experience'].fillna((df_clean['staff_experience'].mode()[0]),inplace = True)
# Out:
# /tmp/ipykernel_11920/262158218.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['staff_experience'].fillna((df_clean['staff_experience'].mode()[0]),inplace = True)
# /tmp/ipykernel_11920/262158218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['staff_experience'].fillna((df_clean['staff_experience'].mode()[0]),inplace = True)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 911 entries, 0 to 910
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                911 non-null    int64
#  1   date              911 non-null    object
#  2   meals_served      911 non-null    int64
#  3   kitchen_staff     911 non-null    int64
#  4   temperature_C     911 non-null    float64
#  5   humidity_percent  911 non-null    float64
#  6   day_of_the_week   911 non-null    int64
#  7   special_event     911 non-null    int64
#  8   past_waste_kg     911 non-null    float64
#  9   staff_experience  911 non-null    object
#  10  waste_category    911 non-null    object
#  11  food_waste_kg     911 non-null    float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 92.5+ KB

# %%
df_clean.isnull().sum()
# Out:
# ID                  0
# date                0
# meals_served        0
# kitchen_staff       0
# temperature_C       0
# humidity_percent    0
# day_of_the_week     0
# special_event       0
# past_waste_kg       0
# staff_experience    0
# waste_category      0
# food_waste_kg       0
# dtype: int64

# %%
# Handling outliers

# %%
numeric_cols = df_clean.select_dtypes(include=np.number).columns.tolist()
numeric_cols
# Out:
# ['ID',
#  'meals_served',
#  'kitchen_staff',
#  'temperature_C',
#  'humidity_percent',
#  'day_of_the_week',
#  'special_event',
#  'past_waste_kg',
#  'food_waste_kg']

# %%
num_df = df_clean[numeric_cols]
num_df
# Out:
#        ID  meals_served  kitchen_staff  temperature_C  humidity_percent  \
# 0       0           196             13      27.887273         45.362854
# 1       1           244             15      10.317872         64.430475
# 2       4           148             16      27.714300         69.046113
# 3       5           157             19      19.173902         46.292823
# 4       6           297             10      26.375233         79.741064
# ..    ...           ...            ...            ...               ...
# 906  1044           395             18      17.354199         45.138435
# 907  1045           483             11      24.912137         59.485091
# 908  1046           243             11      28.870945         70.508404
# 909  1048           406             10      19.061638         55.286642
# 910  1049           350              6      23.708015         51.351286
#
#      day_of_the_week  special_event  past_waste_kg  food_waste_kg
# 0                  0              0       7.740587      28.946465
# 1                  1              0      42.311779      51.549053
# 2                  1              0      41.184305      53.008323
# 3                  6              0      41.543492      48.621527
# 4                  0              0      26.525097      44.156984
# ..               ...            ...            ...            ...
# 906                1              0      40.550668      50.369152
# 907                6              0      36.470276      43.070121
# 908                2              0      19.767203      29.632560
# 909                0              0      28.560361      44.615759
# 910                4              0      46.786860      57.066481
#
# [911 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(15,30))
for i in range(len(numeric_cols)):
    ax=fig.add_subplot(9,5,i+1)
    sns.boxplot(x=num_df.iloc[:,i],ax=ax)

plt.tight_layout()
plt.show()

# %%
Q1=np.quantile(num_df['temperature_C'],0.25)
Q3=np.quantile(num_df['temperature_C'],0.75)
IQR=Q3-Q1

lower_range=Q1-(1.5*IQR)
upper_range=Q3+(1.5*IQR)

print(lower_range)
print(upper_range)
# Out:
# -3.9949789699304024
# 48.4838581484664

# %%
df_clean.shape
# Out:
# (911, 12)

# %%
final_df=df_clean[(df_clean['temperature_C']>=lower_range) & (df_clean['temperature_C']<=upper_range)]
final_df.shape
# Out:
# (889, 12)
